# %%
import time
import requests
#! pip install pymongo[srv]==4.6.2
# Out:
# Collecting pymongo==4.6.2 (from pymongo[srv]==4.6.2)
#   Using cached pymongo-4.6.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (22 kB)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /home/martin/miniconda3/envs/API-bike/lib/python3.12/site-packages (from pymongo==4.6.2->pymongo[srv]==4.6.2) (2.7.0)
# Using cached pymongo-4.6.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (691 kB)
# Installing collected packages: pymongo
#   Attempting uninstall: pymongo
#     Found existing installation: pymongo 4.8.0
#     Uninstalling pymongo-4.8.0:
#       Successfully uninstalled pymongo-4.8.0
# Successfully installed pymongo-4.6.2

# %%
from pymongo import MongoClient

class AtlasClient ():

   def __init__ (self, altas_uri, dbname):
       self.mongodb_client = MongoClient(altas_uri)
       self.database = self.mongodb_client[dbname]

   ## A quick way to test if we can connect to Atlas instance
   def ping (self):
       self.mongodb_client.admin.command('ping')

   def get_collection (self, collection_name):
       collection = self.database[collection_name]
       return collection

   def find (self, collection_name, filter = {}, limit=0):
       collection = self.database[collection_name]
       items = list(collection.find(filter=filter, limit=limit))
       return items

# %%
ATLAS_URI = 'mongodb+srv://admin:admin@citybik-cluster.2wdih.mongodb.net/?retryWrites=true&w=majority&appName=CityBik-Cluster'

DB_NAME = 'bicisCoruña'
COLLECTION_NAME = 'info'

atlas_client = AtlasClient (ATLAS_URI, DB_NAME)
atlas_client.ping()
print ('Connected to Atlas instance! We are good to go!')
# Out:
# Connected to Atlas instance! We are good to go!

# %%
# Conexión al cliente de MongoDB
client = MongoClient(ATLAS_URI)
db = client[DB_NAME]
collection = db[COLLECTION_NAME]

def insert_data():
    url='http://api.citybik.es/v2/networks/bicicorunha'
    try:
        response=requests.get(url)
        data = response.json()
        print(data)
        result = collection.insert_one(data)
        print(f"Inserted {len(result.inserted_ids)} documents with IDs: {result.inserted_ids}")
    except:
        print('Error: ',response.status_code)


intervalo=60

while True:
    insert_data()
    time.sleep(intervalo)
# Out:
# {'network': {'id': 'bicicorunha', 'name': 'Bicicoruña', 'location': {'latitude': 43.3623, 'longitude': -8.4115, 'city': 'A Coruña', 'country': 'ES'}, 'href': '/v2/networks/bicicorunha', 'company': ['PBSC Urban Solutions'], 'gbfs_href': 'https://acoruna.publicbikesystem.net/customer/gbfs/v2/gbfs.json', 'stations': [{'id': '023efce1bbb332a1b918d56aeb671890', 'name': 'Avenida de Arteixo', 'latitude': 43.360755, 'longitude': -8.410942, 'timestamp': '2024-12-11T11:05:45.722772Z', 'free_bikes': 8, 'empty_slots': 7, 'extra': {'uid': '53', 'renting': True, 'returning': True, 'last_updated': 1733914961, 'address': 'Avenida de Arteixo,29', 'post_code': '15007', 'payment': ['key', 'transitcard', 'creditcard', 'phone'], 'payment-terminal': True, 'altitude': 0.0, 'slots': 15, 'normal_bikes': 7, 'ebikes': 1, 'has_ebikes': True, 'rental_uris': {}}}, {'id': '02cecd02915c86d7ab8034b61b19da0e', 'name': 'Mercado de Monte Alto', 'latitude': 43.378, 'longitude': -8.399755, 'timestamp': '2024-12-11T11:05:45.722629Z', 'free_bikes': 1, 'empty_slots': 14, 'extra': {'uid': '43', 'renting': True, 'returning': True, 'last_updated': 1733915039, 'address': 'Calle Antonio Santiago', 'post_code': '15002', 'payment': ['key', 'transitcard', 'creditcard', 'phone'], 'payment-terminal': True, 'altitude': 0.0, 'slots': 15, 'normal_bikes': 0, 'ebikes': 1, 'has_ebikes': True, 'rental_uris': {}}}, {'id': '030c4027b0bea390e562645c7082db4c', 'name': 'Los Rosales', 'latitude': 43.3743246, 'longitude': -8.4319872, 'timestamp': '2024-12-11T11:05:45.721683Z', 'free_bikes': 2, 'empty_slots': 22, 'extra': {'uid': '11', 'renting': True, 'returning': True, 'last_updated': 1733915018, 'address': 'Rúa Emilio González López, 92', 'post_code': '15011', 'payment': ['key', 'transitcard', 'creditcard', 'phone'], 'payment-terminal': True, 'altitude': 0.0, 'slots': 25, 'normal_bikes': 2, 'ebikes': 1, 'has_ebikes': True, 'rental_uris': {}}}, {'id': '0e3aa0134a2f3d07ae5bd093e6af9a33', 'name': 'Plaza de Portugal', 'latitude': 43.3685842, 'longitude': -8.414535, 'timestamp': '2024-12-11T11:05:45.722805Z', 'free_bikes': 7, 'empty_slots': 13, 'extra': {'uid': '55', 'renting': True, 'returning': True, 'last_updated': 1733915019, 'address': 'Av. Habana, S.N', 'post_code': '15011', 'payment': ['key', 'transitcard', 'creditcard', 'phone'], 'payment-terminal': True, 'altitude': 0.0, 'slots': 20, 'normal_bikes': 7, 'ebikes': 0, 'has_ebikes': True, 'rental_uris': {}}}, {'id': '104e0797759d11ac22a61cfed357800b', 'name': 'Ventorrillo', 'latitude': 43.359323, 'longitude': -8.422561, 'timestamp': '2024-12-11T11:05:45.722402Z', 'free_bikes': 3, 'empty_slots': 15, 'extra': {'uid': '27', 'renting': True, 'returning': True, 'last_updated': 1733915103, 'address': 'Plaza Ventorrillo, 0 ', 'post_code': '15010', 'payment': ['key', 'transitcard', 'creditcard', 'phone'], 'payment-terminal': True, 'altitude': 0.0, 'slots': 18, 'normal_bikes': 3, 'ebikes': 0, 'has_ebikes': True, 'rental_uris': {}}}, {'id': '10af3b0e504fc241415d4047a58bfb5b', 'name': 'Cd Castrillón', 'latitude': 43.349334477951, 'longitude': -8.398615367597959, 'timestamp': '2024-12-11T11:05:45.721998Z', 'free_bikes': 5, 'empty_slots': 10, 'extra': {'uid': '23', 'renting': True, 'returning': True, 'last_updated': 1733915045, 'address': 'Av. Casanova de Eirís', 'post_code': '15009', 'payment': ['key', 'transitcard', 'creditcard', 'phone'], 'payment-terminal': True, 'altitude': 0.0, 'slots': 15, 'normal_bikes': 1, 'ebikes': 4, 'has_ebikes': True, 'rental_uris': {}}}, {'id': '15b6693701eb534cddabc0bdd4c3b8a2', 'name': ' Pablo Picasso', 'latitude': 43.346126, 'longitude': -8.410817, 'timestamp': '2024-12-11T11:05:45.722362Z', 'free_bikes': 5, 'empty_slots': 14, 'extra': {'uid': '25', 'renting': True, 'returning': True, 'last_updated': 1733915107, 'address': 'Calle Pintor Luis  Mosquera, 2', 'post_code': '15008', 'payment': ['key', 'transitcard', 'creditcard', 'phone'], 'payment-terminal': True, 'altitude': 0.0, 'slots': 19, 'normal_bikes': 5, 'ebikes': ...
# Error:  200
# {'network': {'id': 'bicicorunha', 'name': 'Bicicoruña', 'location': {'latitude': 43.3623, 'longitude': -8.4115, 'city': 'A Coruña', 'country': 'ES'}, 'href': '/v2/networks/bicicorunha', 'company': ['PBSC Urban Solutions'], 'gbfs_href': 'https://acoruna.publicbikesystem.net/customer/gbfs/v2/gbfs.json', 'stations': [{'id': '023efce1bbb332a1b918d56aeb671890', 'name': 'Avenida de Arteixo', 'latitude': 43.360755, 'longitude': -8.410942, 'timestamp': '2024-12-11T11:08:46.095123Z', 'free_bikes': 8, 'empty_slots': 7, 'extra': {'uid': '53', 'renting': True, 'returning': True, 'last_updated': 1733915144, 'address': 'Avenida de Arteixo,29', 'post_code': '15007', 'payment': ['key', 'transitcard', 'creditcard', 'phone'], 'payment-terminal': True, 'altitude': 0.0, 'slots': 15, 'normal_bikes': 7, 'ebikes': 1, 'has_ebikes': True, 'rental_uris': {}}}, {'id': '02cecd02915c86d7ab8034b61b19da0e', 'name': 'Mercado de Monte Alto', 'latitude': 43.378, 'longitude': -8.399755, 'timestamp': '2024-12-11T11:08:46.094972Z', 'free_bikes': 1, 'empty_slots': 14, 'extra': {'uid': '43', 'renting': True, 'returning': True, 'last_updated': 1733915222, 'address': 'Calle Antonio Santiago', 'post_code': '15002', 'payment': ['key', 'transitcard', 'creditcard', 'phone'], 'payment-terminal': True, 'altitude': 0.0, 'slots': 15, 'normal_bikes': 0, 'ebikes': 1, 'has_ebikes': True, 'rental_uris': {}}}, {'id': '030c4027b0bea390e562645c7082db4c', 'name': 'Los Rosales', 'latitude': 43.3743246, 'longitude': -8.4319872, 'timestamp': '2024-12-11T11:08:46.094469Z', 'free_bikes': 2, 'empty_slots': 22, 'extra': {'uid': '11', 'renting': True, 'returning': True, 'last_updated': 1733915204, 'address': 'Rúa Emilio González López, 92', 'post_code': '15011', 'payment': ['key', 'transitcard', 'creditcard', 'phone'], 'payment-terminal': True, 'altitude': 0.0, 'slots': 25, 'normal_bikes': 2, 'ebikes': 1, 'has_ebikes': True, 'rental_uris': {}}}, {'id': '0e3aa0134a2f3d07ae5bd093e6af9a33', 'name': 'Plaza de Portugal', 'latitude': 43.3685842, 'longitude': -8.414535, 'timestamp': '2024-12-11T11:08:46.095155Z', 'free_bikes': 7, 'empty_slots': 13, 'extra': {'uid': '55', 'renting': True, 'returning': True, 'last_updated': 1733915202, 'address': 'Av. Habana, S.N', 'post_code': '15011', 'payment': ['key', 'transitcard', 'creditcard', 'phone'], 'payment-terminal': True, 'altitude': 0.0, 'slots': 20, 'normal_bikes': 7, 'ebikes': 0, 'has_ebikes': True, 'rental_uris': {}}}, {'id': '104e0797759d11ac22a61cfed357800b', 'name': 'Ventorrillo', 'latitude': 43.359323, 'longitude': -8.422561, 'timestamp': '2024-12-11T11:08:46.094735Z', 'free_bikes': 3, 'empty_slots': 15, 'extra': {'uid': '27', 'renting': True, 'returning': True, 'last_updated': 1733915283, 'address': 'Plaza Ventorrillo, 0 ', 'post_code': '15010', 'payment': ['key', 'transitcard', 'creditcard', 'phone'], 'payment-terminal': True, 'altitude': 0.0, 'slots': 18, 'normal_bikes': 3, 'ebikes': 0, 'has_ebikes': True, 'rental_uris': {}}}, {'id': '10af3b0e504fc241415d4047a58bfb5b', 'name': 'Cd Castrillón', 'latitude': 43.349334477951, 'longitude': -8.398615367597959, 'timestamp': '2024-12-11T11:08:46.094670Z', 'free_bikes': 4, 'empty_slots': 11, 'extra': {'uid': '23', 'renting': True, 'returning': True, 'last_updated': 1733915229, 'address': 'Av. Casanova de Eirís', 'post_code': '15009', 'payment': ['key', 'transitcard', 'creditcard', 'phone'], 'payment-terminal': True, 'altitude': 0.0, 'slots': 15, 'normal_bikes': 1, 'ebikes': 3, 'has_ebikes': True, 'rental_uris': {}}}, {'id': '15b6693701eb534cddabc0bdd4c3b8a2', 'name': ' Pablo Picasso', 'latitude': 43.346126, 'longitude': -8.410817, 'timestamp': '2024-12-11T11:08:46.094700Z', 'free_bikes': 5, 'empty_slots': 14, 'extra': {'uid': '25', 'renting': True, 'returning': True, 'last_updated': 1733915287, 'address': 'Calle Pintor Luis  Mosquera, 2', 'post_code': '15008', 'payment': ['key', 'transitcard', 'creditcard', 'phone'], 'payment-terminal': True, 'altitude': 0.0, 'slots': 19, 'normal_bikes': 5, 'ebikes': ...
# Error:  200
# {'network': {'id': 'bicicorunha', 'name': 'Bicicoruña', 'location': {'latitude': 43.3623, 'longitude': -8.4115, 'city': 'A Coruña', 'country': 'ES'}, 'href': '/v2/networks/bicicorunha', 'company': ['PBSC Urban Solutions'], 'gbfs_href': 'https://acoruna.publicbikesystem.net/customer/gbfs/v2/gbfs.json', 'stations': [{'id': '023efce1bbb332a1b918d56aeb671890', 'name': 'Avenida de Arteixo', 'latitude': 43.360755, 'longitude': -8.410942, 'timestamp': '2024-12-11T11:08:46.095123Z', 'free_bikes': 8, 'empty_slots': 7, 'extra': {'uid': '53', 'renting': True, 'returning': True, 'last_updated': 1733915144, 'address': 'Avenida de Arteixo,29', 'post_code': '15007', 'payment': ['key', 'transitcard', 'creditcard', 'phone'], 'payment-terminal': True, 'altitude': 0.0, 'slots': 15, 'normal_bikes': 7, 'ebikes': 1, 'has_ebikes': True, 'rental_uris': {}}}, {'id': '02cecd02915c86d7ab8034b61b19da0e', 'name': 'Mercado de Monte Alto', 'latitude': 43.378, 'longitude': -8.399755, 'timestamp': '2024-12-11T11:08:46.094972Z', 'free_bikes': 1, 'empty_slots': 14, 'extra': {'uid': '43', 'renting': True, 'returning': True, 'last_updated': 1733915222, 'address': 'Calle Antonio Santiago', 'post_code': '15002', 'payment': ['key', 'transitcard', 'creditcard', 'phone'], 'payment-terminal': True, 'altitude': 0.0, 'slots': 15, 'normal_bikes': 0, 'ebikes': 1, 'has_ebikes': True, 'rental_uris': {}}}, {'id': '030c4027b0bea390e562645c7082db4c', 'name': 'Los Rosales', 'latitude': 43.3743246, 'longitude': -8.4319872, 'timestamp': '2024-12-11T11:08:46.094469Z', 'free_bikes': 2, 'empty_slots': 22, 'extra': {'uid': '11', 'renting': True, 'returning': True, 'last_updated': 1733915204, 'address': 'Rúa Emilio González López, 92', 'post_code': '15011', 'payment': ['key', 'transitcard', 'creditcard', 'phone'], 'payment-terminal': True, 'altitude': 0.0, 'slots': 25, 'normal_bikes': 2, 'ebikes': 1, 'has_ebikes': True, 'rental_uris': {}}}, {'id': '0e3aa0134a2f3d07ae5bd093e6af9a33', 'name': 'Plaza de Portugal', 'latitude': 43.3685842, 'longitude': -8.414535, 'timestamp': '2024-12-11T11:08:46.095155Z', 'free_bikes': 7, 'empty_slots': 13, 'extra': {'uid': '55', 'renting': True, 'returning': True, 'last_updated': 1733915202, 'address': 'Av. Habana, S.N', 'post_code': '15011', 'payment': ['key', 'transitcard', 'creditcard', 'phone'], 'payment-terminal': True, 'altitude': 0.0, 'slots': 20, 'normal_bikes': 7, 'ebikes': 0, 'has_ebikes': True, 'rental_uris': {}}}, {'id': '104e0797759d11ac22a61cfed357800b', 'name': 'Ventorrillo', 'latitude': 43.359323, 'longitude': -8.422561, 'timestamp': '2024-12-11T11:08:46.094735Z', 'free_bikes': 3, 'empty_slots': 15, 'extra': {'uid': '27', 'renting': True, 'returning': True, 'last_updated': 1733915283, 'address': 'Plaza Ventorrillo, 0 ', 'post_code': '15010', 'payment': ['key', 'transitcard', 'creditcard', 'phone'], 'payment-terminal': True, 'altitude': 0.0, 'slots': 18, 'normal_bikes': 3, 'ebikes': 0, 'has_ebikes': True, 'rental_uris': {}}}, {'id': '10af3b0e504fc241415d4047a58bfb5b', 'name': 'Cd Castrillón', 'latitude': 43.349334477951, 'longitude': -8.398615367597959, 'timestamp': '2024-12-11T11:08:46.094670Z', 'free_bikes': 4, 'empty_slots': 11, 'extra': {'uid': '23', 'renting': True, 'returning': True, 'last_updated': 1733915229, 'address': 'Av. Casanova de Eirís', 'post_code': '15009', 'payment': ['key', 'transitcard', 'creditcard', 'phone'], 'payment-terminal': True, 'altitude': 0.0, 'slots': 15, 'normal_bikes': 1, 'ebikes': 3, 'has_ebikes': True, 'rental_uris': {}}}, {'id': '15b6693701eb534cddabc0bdd4c3b8a2', 'name': ' Pablo Picasso', 'latitude': 43.346126, 'longitude': -8.410817, 'timestamp': '2024-12-11T11:08:46.094700Z', 'free_bikes': 5, 'empty_slots': 14, 'extra': {'uid': '25', 'renting': True, 'returning': True, 'last_updated': 1733915287, 'address': 'Calle Pintor Luis  Mosquera, 2', 'post_code': '15008', 'payment': ['key', 'transitcard', 'creditcard', 'phone'], 'payment-terminal': True, 'altitude': 0.0, 'slots': 19, 'normal_bikes': 5, 'ebikes': ...
# Error:  200
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[37], line 22
#      20 while True:
#      21     insert_data()
# ---> 22     time.sleep(intervalo)
#
# KeyboardInterrupt:
