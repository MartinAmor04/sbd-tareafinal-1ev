# %%
import time
import requests

# %%
client = MongoClient('mongodb://localhost:27017/')

db_name = client['bicisCoruña']
collection_name = db_name['info']

ATLAS_URI = 'mongodb+srv://martinamor2004:<db_password>@citybik-cluster.2wdih.mongodb.net/?retryWrites=true&w=majority&appName=CityBik-Cluster'

def conection_to_API():
    url='http://api.citybik.es/v2/networks/bicicorunha'
    try:
        response=requests.get(url)
        data = response.json()
        result = collection_name.insert_many(data)
        print(f"Inserted {len(result.inserted_ids)} documents with IDs: {result.inserted_ids}")
    except:
        print(response.status_code)


intervalo=60

while True:
    conection_to_API()
    time.sleep(intervalo)
# Out:
# 200
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[47], line 23
#      21 while True:
#      22     conection_to_API()
# ---> 23     time.sleep(intervalo)
#
# KeyboardInterrupt:

# %%
from pymongo import MongoClient

class AtlasClient ():

   def __init__ (self, altas_uri, dbname):
       self.mongodb_client = MongoClient(altas_uri)
       self.database = self.mongodb_client[dbname]

   ## A quick way to test if we can connect to Atlas instance
   def ping (self):
       self.mongodb_client.admin.command('ping')

   def get_collection (self, collection_name):
       collection = self.database[collection_name]
       return collection

   def find (self, collection_name, filter = {}, limit=0):
       collection = self.database[collection_name]
       items = list(collection.find(filter=filter, limit=limit))
       return items

# %%
ATLAS_URI = 'mongodb+srv://martinamor2004:<mongo>@citybik-cluster.2wdih.mongodb.net/?retryWrites=true&w=majority&appName=CityBik-Cluster'

DB_NAME = 'bicisCoruña'
COLLECTION_NAME = 'info'

atlas_client = AtlasClient (ATLAS_URI, DB_NAME)
atlas_client.ping()
print ('Connected to Atlas instance! We are good to go!')
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# Cell In[6], line 7
#       4 COLLECTION_NAME = 'info'
#       6 atlas_client = AtlasClient (ATLAS_URI, DB_NAME)
# ----> 7 atlas_client.ping()
#       8 print ('Connected to Atlas instance! We are good to go!')
#
# Cell In[2], line 11, in AtlasClient.ping(self)
#      10 def ping (self):
# ---> 11     self.mongodb_client.admin.command('ping')
#
# File ~/miniconda3/envs/API-bike/lib/python3.12/site-packages/pymongo/_csot.py:107, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     105         with _TimeoutContext(timeout):
#     106             return func(self, *args, **kwargs)
# --> 107 return func(self, *args, **kwargs)
#
# ...

# %%
DB_NAME = 'sample_mflix'
COLLECTION_NAME = 'embedded_movies'

atlas_client = AtlasClient (ATLAS_URI, DB_NAME)
atlas_client.ping()
print ('Connected to Atlas instance! We are good to go!')
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# Cell In[7], line 5
#       2 COLLECTION_NAME = 'embedded_movies'
#       4 atlas_client = AtlasClient (ATLAS_URI, DB_NAME)
# ----> 5 atlas_client.ping()
#       6 print ('Connected to Atlas instance! We are good to go!')
#
# Cell In[2], line 11, in AtlasClient.ping(self)
#      10 def ping (self):
# ---> 11     self.mongodb_client.admin.command('ping')
#
# File ~/miniconda3/envs/API-bike/lib/python3.12/site-packages/pymongo/_csot.py:107, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     105         with _TimeoutContext(timeout):
#     106             return func(self, *args, **kwargs)
# --> 107 return func(self, *args, **kwargs)
#
# ...
